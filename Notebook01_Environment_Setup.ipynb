# %% [markdown]
# # Healthcare Pharma Data Pipeline
#
# ## Notebook 1: Project Setup
#
# ### Objective
# - Verify Spark Session
# - Verify Compute
# - Verify Data Volume
# - Prepare the environment for the ETL pipeline

# %%
spark

# %%
display(dbutils.fs.ls("/Volumes/dbacademy/default/raw_data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/dbacademy/default/raw_data/biotech_funding.csv</td><td>biotech_funding.csv</td><td>90204</td><td>1783146848000</td></tr><tr><td>dbfs:/Volumes/dbacademy/default/raw_data/clinical_trials.csv</td><td>clinical_trials.csv</td><td>55220</td><td>1783229688000</td></tr><tr><td>dbfs:/Volumes/dbacademy/default/raw_data/disease_burden.csv</td><td>disease_burden.csv</td><td>140333</td><td>1783229688000</td></tr><tr><td>dbfs:/Volumes/dbacademy/default/raw_data/drug_approvals.csv</td><td>drug_approvals.csv</td><td>81164</td><td>1783229688000</td></tr><tr><td>dbfs:/Volumes/dbacademy/default/raw_data/pharma_companies_financials.csv</td><td>pharma_companies_financials.csv</td><td>29491</td><td>1783229688000</td></tr></tbody></table></div>

# %%
file_path = "/Volumes/dbacademy/default/raw_data/biotech_funding.csv"

# %%
df = spark.read.csv(file_path, header=True, inferSchema=True)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deal_id</th><th>date</th><th>year</th><th>deal_type</th><th>acquirer_or_investors</th><th>target_or_company</th><th>value_usd_bn</th><th>description</th><th>is_megadeal</th><th>is_real_headline</th></tr></thead><tbody><tr><td>D0001</td><td>2009-03-09</td><td>2009</td><td>M&A</td><td>Pfizer</td><td>Wyeth</td><td>68.0</td><td>Pfizer-Wyeth megamerger</td><td>1</td><td>1</td></tr><tr><td>D0041</td><td>2010-01-08</td><td>2010</td><td>Series_B</td><td>F-Prime Capital</td><td>Oncgen OS</td><td>0.403</td><td>Series_B 2010</td><td>0</td><td>0</td></tr><tr><td>D0036</td><td>2010-01-12</td><td>2010</td><td>IPO</td><td>Public markets</td><td>Yothap IO</td><td>0.456</td><td>IPO 2010</td><td>0</td><td>0</td></tr><tr><td>D0045</td><td>2010-01-16</td><td>2010</td><td>M&A</td><td>Roche</td><td>Aermod AB</td><td>1.158</td><td>M&A 2010</td><td>0</td><td>0</td></tr><tr><td>D0053</td><td>2010-01-17</td><td>2010</td><td>Series_B</td><td>Polaris Partners</td><td>Tavyot OS</td><td>0.643</td><td>Series_B 2010</td><td>0</td><td>0</td></tr><tr><td>D0046</td><td>2010-01-17</td><td>2010</td><td>Crossover</td><td>GV (Google Ventures)</td><td>Repyot RX</td><td>0.348</td><td>Crossover 2010</td><td>0</td><td>0</td></tr><tr><td>D0032</td><td>2010-01-18</td><td>2010</td><td>M&A</td><td>Sanofi</td><td>Quoxen BIO</td><td>0.247</td><td>M&A 2010</td><td>0</td><td>0</td></tr><tr><td>D0049</td><td>2010-01-23</td><td>2010</td><td>VC</td><td>ARCH Venture Partners</td><td>Jasquo RX</td><td>0.096</td><td>VC 2010</td><td>0</td><td>0</td></tr><tr><td>D0028</td><td>2010-02-03</td><td>2010</td><td>M&A</td><td>Roche</td><td>Repquo BIO</td><td>0.046</td><td>M&A 2010</td><td>0</td><td>0</td></tr><tr><td>D0042</td><td>2010-02-09</td><td>2010</td><td>IPO</td><td>Public markets</td><td>Quorep OS</td><td>0.232</td><td>IPO 2010</td><td>0</td><td>0</td></tr><tr><td>D0040</td><td>2010-02-09</td><td>2010</td><td>VC</td><td>Versant Ventures</td><td>Neusyn GX</td><td>0.078</td><td>VC 2010</td><td>0</td><td>0</td></tr><tr><td>D0052</td><td>2010-02-14</td><td>2010</td><td>M&A</td><td>Amgen</td><td>Probio BIO</td><td>0.174</td><td>M&A 2010</td><td>0</td><td>0</td></tr><tr><td>D0062</td><td>2010-02-16</td><td>2010</td><td>Series_C</td><td>Sofinnova Investments</td><td>Quomod OS</td><td>0.12</td><td>Series_C 2010</td><td>0</td><td>0</td></tr><tr><td>D0029</td><td>2010-02-23</td><td>2010</td><td>Crossover</td><td>F-Prime Capital</td><td>Reptav X</td><td>0.026</td><td>Crossover 2010</td><td>0</td><td>0</td></tr><tr><td>D0030</td><td>2010-02-25</td><td>2010</td><td>M&A</td><td>GSK</td><td>Lumquo BIO</td><td>0.506</td><td>M&A 2010</td><td>0</td><td>0</td></tr><tr><td>D0058</td><td>2010-03-10</td><td>2010</td><td>IPO</td><td>Public markets</td><td>Quoxen AB</td><td>0.463</td><td>IPO 2010</td><td>0</td><td>0</td></tr><tr><td>D0060</td><td>2010-04-06</td><td>2010</td><td>VC</td><td>GV (Google Ventures)</td><td>Repjas GX</td><td>1.037</td><td>VC 2010</td><td>0</td><td>0</td></tr><tr><td>D0037</td><td>2010-04-08</td><td>2010</td><td>M&A</td><td>BMS</td><td>Celkym Tx</td><td>3.473</td><td>M&A 2010</td><td>0</td><td>0</td></tr><tr><td>D0056</td><td>2010-04-14</td><td>2010</td><td>Series_C</td><td>Flagship Pioneering</td><td>Uniden IO</td><td>0.081</td><td>Series_C 2010</td><td>0</td><td>0</td></tr><tr><td>D0043</td><td>2010-04-18</td><td>2010</td><td>VC</td><td>Atlas Venture</td><td>Biotav AB</td><td>0.154</td><td>VC 2010</td><td>0</td><td>0</td></tr><tr><td>D0050</td><td>2010-05-12</td><td>2010</td><td>VC</td><td>Bain Capital Life Sciences</td><td>Biozeo IO</td><td>0.729</td><td>VC 2010</td><td>0</td><td>0</td></tr><tr><td>D0038</td><td>2010-05-19</td><td>2010</td><td>Crossover</td><td>OrbiMed</td><td>Immpro Tx</td><td>0.166</td><td>Crossover 2010</td><td>0</td><td>0</td></tr><tr><td>D0047</td><td>2010-05-19</td><td>2010</td><td>M&A</td><td>J&J</td><td>Neumod Tx</td><td>3.141</td><td>M ...

# %%
df.count()
# Out:
# 1208

# %%
df.printSchema()
# Out:
# root
#  |-- deal_id: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- deal_type: string (nullable = true)
#  |-- acquirer_or_investors: string (nullable = true)
#  |-- target_or_company: string (nullable = true)
#  |-- value_usd_bn: double (nullable = true)
#  |-- description: string (nullable = true)
#  |-- is_megadeal: integer (nullable = true)
#  |-- is_real_headline: integer (nullable = true)

# %%
df.show(5)
# Out:
# +-------+----------+----+---------+---------------------+-----------------+------------+--------------------+-----------+----------------+
# |deal_id|      date|year|deal_type|acquirer_or_investors|target_or_company|value_usd_bn|         description|is_megadeal|is_real_headline|
# +-------+----------+----+---------+---------------------+-----------------+------------+--------------------+-----------+----------------+
# |  D0001|2009-03-09|2009|      M&A|               Pfizer|            Wyeth|        68.0|Pfizer-Wyeth mega...|          1|               1|
# |  D0041|2010-01-08|2010| Series_B|      F-Prime Capital|        Oncgen OS|       0.403|       Series_B 2010|          0|               0|
# |  D0036|2010-01-12|2010|      IPO|       Public markets|        Yothap IO|       0.456|            IPO 2010|          0|               0|
# |  D0045|2010-01-16|2010|      M&A|                Roche|        Aermod AB|       1.158|            M&A 2010|          0|               0|
# |  D0053|2010-01-17|2010| Series_B|     Polaris Partners|        Tavyot OS|       0.643|       Series_B 2010|          0|               0|
# +-------+----------+----+---------+---------------------+-----------------+------------+--------------------+-----------+----------------+
# only showing top 5 rows
