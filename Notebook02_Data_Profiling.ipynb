# %% [markdown]
# # Healthcare Pharma Data Pipeline
#
# ## Notebook 2: Data Exploration
#
# ### Objective
#
# - Understand the dataset
# - Check schema
# - Count records
# - Identify null values
# - Identify duplicate records
# - Understand business meaning

# %%
file_path = "/Volumes/dbacademy/default/raw_data/biotech_funding.csv"

df = spark.read.csv(
    file_path,
    header=True,
    inferSchema=True
)

# %%
df.count()
# Out:
# 1208

# %%
len(df.columns)
# Out:
# 10

# %%
df.columns
# Out:
# ['deal_id',
#  'date',
#  'year',
#  'deal_type',
#  'acquirer_or_investors',
#  'target_or_company',
#  'value_usd_bn',
#  'description',
#  'is_megadeal',
#  'is_real_headline']

# %%
from pyspark.sql.functions import col, sum

# %%
df.select([
    sum(col(c).isNull().cast("int")).alias(c)
    for c in df.columns
]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deal_id</th><th>date</th><th>year</th><th>deal_type</th><th>acquirer_or_investors</th><th>target_or_company</th><th>value_usd_bn</th><th>description</th><th>is_megadeal</th><th>is_real_headline</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
df.count()
# Out:
# 1208

# %%
df.distinct().count()
# Out:
# 1208

# %%
from pyspark.sql.functions import count

# %%
df.groupBy("deal_id").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deal_id</th><th>count</th></tr></thead><tbody><tr><td>D0056</td><td>1</td></tr><tr><td>D0085</td><td>1</td></tr><tr><td>D0149</td><td>1</td></tr><tr><td>D0172</td><td>1</td></tr><tr><td>D0164</td><td>1</td></tr><tr><td>D0262</td><td>1</td></tr><tr><td>D0254</td><td>1</td></tr><tr><td>D0263</td><td>1</td></tr><tr><td>D0340</td><td>1</td></tr><tr><td>D0295</td><td>1</td></tr><tr><td>D0316</td><td>1</td></tr><tr><td>D0308</td><td>1</td></tr><tr><td>D0306</td><td>1</td></tr><tr><td>D0356</td><td>1</td></tr><tr><td>D0380</td><td>1</td></tr><tr><td>D0345</td><td>1</td></tr><tr><td>D0396</td><td>1</td></tr><tr><td>D0393</td><td>1</td></tr><tr><td>D0447</td><td>1</td></tr><tr><td>D0411</td><td>1</td></tr><tr><td>D0484</td><td>1</td></tr><tr><td>D0519</td><td>1</td></tr><tr><td>D0496</td><td>1</td></tr><tr><td>D0532</td><td>1</td></tr><tr><td>D0542</td><td>1</td></tr><tr><td>D0499</td><td>1</td></tr><tr><td>D0511</td><td>1</td></tr><tr><td>D0550</td><td>1</td></tr><tr><td>D0614</td><td>1</td></tr><tr><td>D0583</td><td>1</td></tr><tr><td>D0668</td><td>1</td></tr><tr><td>D0684</td><td>1</td></tr><tr><td>D0702</td><td>1</td></tr><tr><td>D0639</td><td>1</td></tr><tr><td>D0805</td><td>1</td></tr><tr><td>D0742</td><td>1</td></tr><tr><td>D0758</td><td>1</td></tr><tr><td>D0734</td><td>1</td></tr><tr><td>D0841</td><td>1</td></tr><tr><td>D0835</td><td>1</td></tr><tr><td>D0932</td><td>1</td></tr><tr><td>D0933</td><td>1</td></tr><tr><td>D0889</td><td>1</td></tr><tr><td>D0902</td><td>1</td></tr><tr><td>D0918</td><td>1</td></tr><tr><td>